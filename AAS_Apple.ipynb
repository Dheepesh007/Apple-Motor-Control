# %%
import pandas as pd

data = pd.DataFrame({
    "distance": [5],
    "time": [2]
})

data.to_csv("motor_dataset.csv", index=False)

# %%
# Motor speed calculation

# sample dataset values
distance = 5.0   # meters
time = 2.0       # seconds

# calculate speed
speed = distance / time

print("Motor Speed:", speed, "m/s")
# Out:
# Motor Speed: 2.5 m/s
